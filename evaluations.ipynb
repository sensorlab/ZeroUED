# %%
# !pip install torch
# !pip install torchvision
# !pip install torch-dct
# !pip install wandb
# !pip install PyWavelets
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.11/site-packages (2.6.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.11/site-packages (from torch) (4.13.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch) (3.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.11/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/conda/lib/python3.11/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/conda/lib/python3.11/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/conda/lib/python3.11/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/conda/lib/python3.11/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/conda/lib/python3.11/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /opt/conda/lib/python3.11/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/conda/lib/python3.11/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /opt/conda/lib/python3.11/site-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/conda/lib/python3.11/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.11/site-packages (0.21.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from torchvision) (1.24.4)
# Requirement already satisfied: torch==2.6.0 in /opt/conda/lib/python3.11/site-packages (from torchvision) (2.6.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from torchvision) (10.1.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (4.13.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (3.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/conda/lib/python3.11/site-packages (from torch==2.6.0->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy==1.13.1->torch==2.6.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch==2.6.0->torchvision) (2.1.3)
# Requirement already satisfied: torch-dct in /opt/conda/lib/python3.11/site-packages (0.1.6)
# Requirement already satisfied: torch>=0.4.1 in /opt/conda/lib/python3.11/site-packages (from torch-dct) (2.6.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (4.13.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (3.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (2023.9.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/conda/lib/python3.11/site-packages (from torch>=0.4.1->torch-dct) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy==1.13.1->torch>=0.4.1->torch-dct) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=0.4.1->torch-dct) (2.1.3)
# Requirement already satisfied: wandb in /opt/conda/lib/python3.11/site-packages (0.19.9)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.11/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from wandb) (3.1.40)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.11/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.11/site-packages (from wandb) (4.24.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.11/site-packages (from wandb) (5.9.5)
# Requirement already satisfied: pydantic<3 in /opt/conda/lib/python3.11/site-packages (from wandb) (2.11.2)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from wandb) (2.31.0)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from wandb) (2.25.1)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.11/site-packages (from wandb) (1.3.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from wandb) (68.2.2)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /opt/conda/lib/python3.11/site-packages (from wandb) (4.13.1)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.11/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /opt/conda/lib/python3.11/site-packages (from pydantic<3->wandb) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.11/site-packages (from pydantic<3->wandb) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3,>=2.0.0->wandb) (2023.7.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (3.0.5)
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.11/site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.11/site-packages (from PyWavelets) (1.24.4)

# %%
import useful_utils

# %%
import wandb
wandb.login()
#wandb.finish()
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# True

# %%
configs = {
    
    'num_iterations': 1,     # iterations for each config
    'starting_iteration': 0, # start id of iteration
    'exp_id': 'test_2',        # id of current run
    'logs_dir': 'logs',      # dir for logs
    'report_interval': 5,    # report interval

    # dataset specification
    
    'dataset': {
        'name':  'WiSig',           # name in [WiSig, LoRa, Drones]
        'config': {
            
            'file': 'ManyTx.pkl',   # file path for WiSig
            
            'k_fold': {             # sepcifcation for k_fold
                'total_devices': 10,
                'ratio': 2
            },
            
        },
    },

    # train and test loaders
    
    'train_loader': {
        'num_workers': 1,
        'batch_size' : 10,
        'shuffle' : True
    },

    'test_loader': {
        'num_workers' : 1,
        'batch_size' : 10,
        'shuffle' : False
    },

    # specificaions for metrics computing 

    'evaluation': {
        'clusters_numbers': (20,30,40) # for wich numers if clusters calculate metrics
    },


    # specificaions for approach and trainer parameters
    
    'approach': {
        'name': 'AE',
        'config': {
            'noise_std': 0.1,
            "device": 'cuda',
            "num_epochs": 20
        },
        'trainer' : {
            'main_optimizer' : {
                'name': 'Adam',
                'config': {'lr': [1e-4, 1e-5]} # ranges are supported
            },
            
        }
    },

    # specificaions for feature_extractor
                
    'feature_extractor': {
        'name': 'AE_CNN_1D',
        'config' : {
            'input_signal_length': 256,
            'in_channels': 2,
            'kernel_size_maxpool': 2
        }
    }
    
}

# %%
for config in useful_utils.parse_configs(configs):
    useful_utils.evauate_config(config)
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>20_accuracy</td><td>█▁</td></tr><tr><td>20_calinski_harabasz_test</td><td>█▁</td></tr><tr><td>20_calinski_harabasz_train</td><td>█▁</td></tr><tr><td>20_davies_bouldin_test</td><td>▁█</td></tr><tr><td>20_davies_bouldin_train</td><td>▁█</td></tr><tr><td>20_f1</td><td>█▁</td></tr><tr><td>20_precision</td><td>█▁</td></tr><tr><td>20_recall</td><td>█▁</td></tr><tr><td>20_roc_auc</td><td>█▁</td></tr><tr><td>20_silhouette_test</td><td>▁█</td></tr><tr><td>20_silhouette_train</td><td>█▁</td></tr><tr><td>30_accuracy</td><td>█▁</td></tr><tr><td>30_calinski_harabasz_test</td><td>█▁</td></tr><tr><td>30_calinski_harabasz_train</td><td>█▁</td></tr><tr><td>30_davies_bouldin_test</td><td>▁█</td></tr><tr><td>30_davies_bouldin_train</td><td>▁█</td></tr><tr><td>30_f1</td><td>█▁</td></tr><tr><td>30_precision</td><td>█▁</td></tr><tr><td>30_recall</td><td>█▁</td></tr><tr><td>30_roc_auc</td><td>█▁</td></tr><tr><td>30_silhouette_test</td><td>█▁</td></tr><tr><td>30_silhouette_train</td><td>█▁</td></tr><tr><td>40_accuracy</td><td>▁█</td></tr><tr><td>40_calinski_harabasz_test</td><td>█▁</td></tr><tr><td>40_calinski_harabasz_train</td><td>█▁</td></tr><tr><td>40_davies_bouldin_test</td><td>█▁</td></tr><tr><td>40_davies_bouldin_train</td><td>█▁</td></tr><tr><td>40_f1</td><td>▁█</td></tr><tr><td>40_precision</td><td>▁█</td></tr><tr><td>40_recall</td><td>▁█</td></tr><tr><td>40_roc_auc</td><td>█▁</td></tr><tr><td>40_silhouette_test</td><td>█▁</td></tr><tr><td>40_silhouette_train</td><td>█▁</td></tr><tr><td>loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>20_accuracy</td><td>0.54787</td></tr><tr><td>20_calinski_harabasz_test</td><td>6646.8152</td></tr><tr><td>20_calinski_harabasz_train</td><td>3287.93062</td></tr><tr><td>20_davies_bouldin_test</td><td>1.33523</td></tr><tr><td>20_davies_bouldin_train</td><td>1.3225</td></tr><tr><td>20_f1</td><td>0.23555</td></tr><tr><td>20_precision</td><td>0.73197</td></tr><tr><td>20_recall</td><td>0.14036</td></tr><tr><td>20_roc_auc</td><td>0.63044</td></tr><tr><td>20_silhouette_test</td><td>0.41779</td></tr><tr><td>20_silhouette_train</td><td>0.40297</td></tr><tr><td>30_accuracy</td><td>0.54963</td></tr><tr><td>30_calinski_harabasz_test</td><td>5329.06985</td></tr><tr><td>30_calinski_harabasz_train</td><td>2659.09901</td></tr><tr><td>30_davies_bouldin_test</td><td>1.45101</td></tr><tr><td>30_davies_bouldin_train</td><td>1.41844</td></tr><tr><td>30_f1</td><td>0.2397</td></tr><tr><td>30_precision</td><td>0.73894</td></tr><tr><td>30_recall</td><td>0.14305</td></tr><tr><td>30_roc_auc</td><td>0.63602</td></tr><tr><td>30_silhouette_test</td><td>0.31652</td></tr><tr><td>30_silhouette_train</td><td>0.31301</td></tr><tr><td>40_accuracy</td><td>0.59354</td></tr><tr><td>40_calinski_harabasz_test</td><td>4498.57455</td></tr><tr><td>40_calinski_harabasz_train</td><td>2303.00628</td></tr><tr><td>40_davies_bouldin_test</td><td>1.41552</td></tr><tr><td>40_davies_bouldin_train</td><td>1.36748</td></tr><tr><td>40_f1</td><td>0.36196</td></tr><tr><td>40_precision</td><td>0.81903</td></tr><tr><td>40_recall</td><td>0.23232</td></tr><tr><td>40_roc_auc</td><td>0.63449</td></tr><tr><td>40_silhouette_test</td><td>0.31163</td></tr><tr><td>40_silhouette_train</td><td>0.3103</td></tr><tr><td>loss</td><td>0.3009</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fold_1, iter_0, approach_AE, f_extractor_AE_CNN_1D</strong> at: <a href='https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations/runs/qrxafklc' target="_blank">https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations/runs/qrxafklc</a><br> View project at: <a href='https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations' target="_blank">https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250404_072318-qrxafklc/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/home/jovyan/SignalSage/wandb/run-20250404_073526-gvpkzpew</code>
# Syncing run <strong><a href='https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations/runs/gvpkzpew' target="_blank">fold_0, iter_0, approach_AE, f_extractor_AE_CNN_1D</a></strong> to <a href='https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations' target="_blank">https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations</a>
#  View run at <a href='https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations/runs/gvpkzpew' target="_blank">https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations/runs/gvpkzpew</a>
# 19.501144 19.501144
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 19.501144 19.501144
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 19.501144 19.501144
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 18.500307 12.35203
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 18.500307 12.35203
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 18.500307 12.35203
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 18.739914 12.524478
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 18.739914 12.524478
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 18.739914 12.524478
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 20.331009 12.662872
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 20.331009 12.662872
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 20.331009 12.662872
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>20_accuracy</td><td>█▁▁▂</td></tr><tr><td>20_calinski_harabasz_test</td><td>█▃▂▁</td></tr><tr><td>20_calinski_harabasz_train</td><td>█▃▂▁</td></tr><tr><td>20_davies_bouldin_test</td><td>▁▆▇█</td></tr><tr><td>20_davies_bouldin_train</td><td>▁▆▇█</td></tr><tr><td>20_f1</td><td>█▁▁▂</td></tr><tr><td>20_precision</td><td>█▁▂▂</td></tr><tr><td>20_recall</td><td>█▁▁▂</td></tr><tr><td>20_roc_auc</td><td>▁█▇█</td></tr><tr><td>20_silhouette_test</td><td>█▁▃▃</td></tr><tr><td>20_silhouette_train</td><td>█▁▂▂</td></tr><tr><td>30_accuracy</td><td>▄█▁▅</td></tr><tr><td>30_calinski_harabasz_test</td><td>█▃▁▂</td></tr><tr><td>30_calinski_harabasz_train</td><td>█▃▁▁</td></tr><tr><td>30_davies_bouldin_test</td><td>▁▆█▅</td></tr><tr><td>30_davies_bouldin_train</td><td>▁▅█▆</td></tr><tr><td>30_f1</td><td>▄█▁▅</td></tr><tr><td>30_precision</td><td>▅█▁▅</td></tr><tr><td>30_recall</td><td>▄█▁▅</td></tr><tr><td>30_roc_auc</td><td>▁█▆▄</td></tr><tr><td>30_silhouette_test</td><td>▁█▆▅</td></tr><tr><td>30_silhouette_train</td><td>▁█▆▃</td></tr><tr><td>40_accuracy</td><td>▄█▁▆</td></tr><tr><td>40_calinski_harabasz_test</td><td>█▂▁▁</td></tr><tr><td>40_calinski_harabasz_train</td><td>█▃▂▁</td></tr><tr><td>40_davies_bouldin_test</td><td>▁█▇█</td></tr><tr><td>40_davies_bouldin_train</td><td>▁▇██</td></tr><tr><td>40_f1</td><td>▄█▁▆</td></tr><tr><td>40_precision</td><td>▅█▁▆</td></tr><tr><td>40_recall</td><td>▄█▁▆</td></tr><tr><td>40_roc_auc</td><td>▁▇▄█</td></tr><tr><td>40_silhouette_test</td><td>█▁▁▂</td></tr><tr><td>40_silhouette_train</td><td>█▂▁▁</td></tr><tr><td>loss</td><td>█▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>20_accuracy</td><td>0.52868</td></tr><tr><td>20_calinski_harabasz_test</td><td>6390.85098</td></tr><tr><td>20_calinski_harabasz_train</td><td>3621.09428</td></tr><tr><td>20_davies_bouldin_test</td><td>1.43181</td></tr><tr><td>20_davies_bouldin_train</td><td>1.37748</td></tr><tr><td>20_f1</td><td>0.19517</td></tr><tr><td>20_precision</td><td>0.69781</td></tr><tr><td>20_recall</td><td>0.11345</td></tr><tr><td>20_roc_auc</td><td>0.65079</td></tr><tr><td>20_silhouette_test</td><td>0.41639</td></tr><tr><td>20_silhouette_train</td><td>0.4516</td></tr><tr><td>30_accuracy</td><td>0.55343</td></tr><tr><td>30_calinski_harabasz_test</td><td>5160.68595</td></tr><tr><td>30_calinski_harabasz_train</td><td>2926.8453</td></tr><tr><td>30_davies_bouldin_test</td><td>1.46187</td></tr><tr><td>30_davies_bouldin_train</td><td>1.43382</td></tr><tr><td>30_f1</td><td>0.26922</td></tr><tr><td>30_precision</td><td>0.76612</td></tr><tr><td>30_recall</td><td>0.1633</td></tr><tr><td>30_roc_auc</td><td>0.64856</td></tr><tr><td>30_silhouette_test</td><td>0.37544</td></tr><tr><td>30_silhouette_train</td><td>0.41898</td></tr><tr><td>40_accuracy</td><td>0.5595</td></tr><tr><td>40_calinski_harabasz_test</td><td>4306.81134</td></tr><tr><td>40_calinski_harabasz_train</td><td>2501.98633</td></tr><tr><td>40_davies_bouldin_test</td><td>1.53823</td></tr><tr><td>40_davies_bouldin_train</td><td>1.48794</td></tr><tr><td>40_f1</td><td>0.28555</td></tr><tr><td>40_precision</td><td>0.78014</td></tr><tr><td>40_recall</td><td>0.17475</td></tr><tr><td>40_roc_auc</td><td>0.66982</td></tr><tr><td>40_silhouette_test</td><td>0.30619</td></tr><tr><td>40_silhouette_train</td><td>0.32236</td></tr><tr><td>loss</td><td>0.26735</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fold_0, iter_0, approach_AE, f_extractor_AE_CNN_1D</strong> at: <a href='https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations/runs/gvpkzpew' target="_blank">https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations/runs/gvpkzpew</a><br> View project at: <a href='https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations' target="_blank">https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250404_073526-gvpkzpew/logs</code>
# Tracking run with wandb version 0.19.9
# Run data is saved locally in <code>/home/jovyan/SignalSage/wandb/run-20250404_074518-jwtliaql</code>
# Syncing run <strong><a href='https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations/runs/jwtliaql' target="_blank">fold_1, iter_0, approach_AE, f_extractor_AE_CNN_1D</a></strong> to <a href='https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations' target="_blank">https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations</a>
#  View run at <a href='https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations/runs/jwtliaql' target="_blank">https://wandb.ai/mik044347-jozef-stefan-institute/WiSig_evaluations/runs/jwtliaql</a>
# 13.402899 13.402899
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 13.402899 13.402899
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 13.402899 13.402899
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /opt/conda/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
